# %% [markdown]
# <a href="https://colab.research.google.com/github/WildanNurRohmat/wildannurrohmat.github.io/blob/main/UAS_Visualisasi_WildanNurR_TI_6A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !pip install pandas matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-49ee18c7-b633-47a2-86f4-5c12f4fe25b8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-49ee18c7-b633-47a2-86f4-5c12f4fe25b8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a7b36eae-8912-42e3-9c8c-2453f72df169" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a7b36eae-8912-42e3-9c8c-2453f72df169">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data2 = pd.read_csv('kebutuhan_per_bulan_2.csv')
data2
# Out:
#            Propinsi  tahun kebutuhan
# 0              ACEH   2005    619876
# 1    SUMATERA UTARA   2005    547255
# 2    SUMATERA BARAT   2005    501315
# 3              RIAU   2005    551498
# 4             JAMBI   2005    495242
# ..              ...    ...       ...
# 369  SULAWESI BARAT   2015   1981507
# 370          MALUKU   2015   2197450
# 371    MALUKU UTARA   2015   2333166
# 372     PAPUA BARAT   2015   2255113
# 373           PAPUA   2015   2171944
#
# [374 rows x 3 columns]

# %%
print(data2.head())
# Out:
#          Propinsi  tahun kebutuhan
# 0            ACEH   2005    619876
# 1  SUMATERA UTARA   2005    547255
# 2  SUMATERA BARAT   2005    501315
# 3            RIAU   2005    551498
# 4           JAMBI   2005    495242

# %%
x = data2['tahun']
y = data2['kebutuhan']

plt.scatter(x, y)

plt.xlabel('tahun')
plt.ylabel('kebutuhan')

plt.title('Kebutuhan Perbulan 2')

plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1a4b2b68-90d0-4edf-ab25-9f680fffb013" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1a4b2b68-90d0-4edf-ab25-9f680fffb013">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#data Produk.CSV error tidak bisa di gunakan

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ba944608-3117-4154-a1ba-2c50a3333093" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ba944608-3117-4154-a1ba-2c50a3333093">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data4 = pd.read_csv('profile_pelanggan.csv')
data4
# Out:
#       15572  DKI Jakarta
# 0     12461   Jawa Timur
# 1     12590   Jawa Barat
# 2     16839  DKI Jakarta
# 3     13596  DKI Jakarta
# 4     12395    Luar Jawa
# ...     ...          ...
# 2352  18261  DKI Jakarta
# 2353  18257  DKI Jakarta
# 2354  12510  Jawa Tengah
# 2355  16198  DKI Jakarta
# 2356  16235  DKI Jakarta
#
# [2357 rows x 2 columns]

# %%
print(data4.head())
# Out:
#    15572  DKI Jakarta
# 0  12461   Jawa Timur
# 1  12590   Jawa Barat
# 2  16839  DKI Jakarta
# 3  13596  DKI Jakarta
# 4  12395    Luar Jawa

# %%
x = data4['15572']
y = data4['DKI Jakarta']

plt.scatter(x, y)

plt.xlabel('15572')
plt.ylabel('DKI Jakarta')

plt.title('Profile Pelanggan')

plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8b2328e2-ff9e-4bbb-be8f-b154d665f0cc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8b2328e2-ff9e-4bbb-be8f-b154d665f0cc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data5 = pd.read_csv('SupplyKantor.csv')
data5
# Out:
#    TanggalPesan        Kota SalesRep    Jenis  Jumlah  Harga Satuan
# 0     30-Mar-17     Jakarta  Richard  Pen Set      62          4990
# 1     07-Apr-17    Surabaya     Nono   Binder      29          1990
# 2     16-Apr-17    Surabaya     Nono  Pen Set      55         12490
# 3     24-Apr-17     Bandung    Susan   Binder      81         19990
# 4     03-May-17    Surabaya    Mamat  Pen Set      42         23950
# 5     11-May-17     Jakarta  Richard   Pencil      35          4990
# 6     20-May-17  Yogyakarta   Jajang     Desk       3        275000
# 7     28-May-17     Bandung    Smith     Desk       2        125000
# 8     06-Jun-17     Bandung     Bobi   Pencil       7          1290
# 9     14-Jun-17     Jakarta  Richard  Pen Set      16         15990
# 10    23-Jun-17  Yogyakarta   Jajang      Pen      76          1990
# 11    01-Jul-17     Bandung   Morgan   Binder      28          8990
# 12    10-Jul-17     Bandung   Thomas   Binder      57         19990
# ...

# %%
print(data5.head())
# Out:
#   TanggalPesan      Kota SalesRep    Jenis  Jumlah  Harga Satuan
# 0    30-Mar-17   Jakarta  Richard  Pen Set      62          4990
# 1    07-Apr-17  Surabaya     Nono   Binder      29          1990
# 2    16-Apr-17  Surabaya     Nono  Pen Set      55         12490
# 3    24-Apr-17   Bandung    Susan   Binder      81         19990
# 4    03-May-17  Surabaya    Mamat  Pen Set      42         23950

# %%
x = data5['Jumlah']
y = data5['SalesRep']

plt.scatter(x, y)

plt.xlabel('Jumlah')
plt.ylabel('SalesRep')

plt.title('Supply Kantor')

plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a542d2e5-a5f6-4406-bb33-d421e32e55ac" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a542d2e5-a5f6-4406-bb33-d421e32e55ac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data6 = pd.read_csv('transaksi2.csv')
data6
# Out:
#       2017-05-03 11:43:20  22704   25  15572
# 0     2017-09-04 07:16:20  22081   10  12461
# 1     2017-07-09 11:39:20  22989  100  12590
# 2     2017-03-20 12:18:20  22629   64  16839
# 3     2018-01-24 08:50:20  21615    1  13596
# 4     2018-01-17 12:14:20  84375   12  12395
# ...                   ...    ...  ...    ...
# 7463  2018-01-24 09:17:20  22510    1  18156
# 7464  2018-02-02 09:49:20  20771    2  14606
# 7465  2017-03-23 12:52:20  22493   12  17001
# 7466  2017-10-25 10:28:20  23118    2  15856
# 7467  2017-07-19 09:54:20  23184    2  14769
#
# [7468 rows x 4 columns]

# %%
print(data6.head())
# Out:
#    2017-05-03 11:43:20  22704   25  15572
# 0  2017-09-04 07:16:20  22081   10  12461
# 1  2017-07-09 11:39:20  22989  100  12590
# 2  2017-03-20 12:18:20  22629   64  16839
# 3  2018-01-24 08:50:20  21615    1  13596
# 4  2018-01-17 12:14:20  84375   12  12395

# %%
x = data6['22704']
y = data6['25']

plt.scatter(x, y)

plt.xlabel('Waktu')
plt.ylabel('Kode')

plt.title('Data Transaksi')

plt.show()

# %%
x1 = data5['Jumlah']
y1 = data5['SalesRep']
x2 = data5['Jenis']
y2 = data5['Kota']


plt.scatter(x1, y1, label='data1', color='r')
plt.scatter(x2, y2, label='data2', color='b')

plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')

plt.title('Data Gabungan')

plt.legend()
plt.show()

# %%
x1 = data2['Propinsi']
y1 = data2['tahun']
x2 = data5['Jumlah']
y2 = data5['SalesRep']



plt.scatter(x1, y1, label='data1', color='r')
plt.scatter(x2, y2, label='data2', color='b')

plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')

plt.title('Data Gabungan Beda File')

plt.legend()
plt.show()
